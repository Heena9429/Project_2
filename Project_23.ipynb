# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Dataset-1

# %%
dataset_1= r"C:\Users\DELL\Documents\dataset_1.csv"
df1 = pd.read_csv(dataset_1)
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
# No. of rows and columns in Dataset-1
df1.shape
# Out:
# (610, 10)

# %%
# print Top 5 rows
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
# print last 5 rows
df1.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
df1 = pd.DataFrame(df1)
df1.head()
column_list = list(df1.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp']

# %%
# Datatypes 
df1.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# dtype: object

# %%
# checking the description
df1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
# Checking for any N/A values
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
# Checking for any duplicates values
df1.duplicated().sum()
# Out:
# 0

# %%
missing_value_df1 = df1.isnull().sum()
print("\n missing value in dataset 1: \n" , missing_value_df1)
# Out:
#  missing value in dataset 1:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %% [markdown]
# # Data Visulaization

# %% [markdown]
# #### Importing Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Line plot
x = np.linspace(0.2, 0.46, 100)
y = np.sin(x)

# Create a new figure
plt.figure(figsize=(10,6))

# Plot the data
plt.plot(x,y)

# Add lables and title
plt.xlabel('Temprature')
plt.ylabel('Season')
plt.title('Line Plot')

# Show the plot
plt.show()

# %%
# Bar Graph
season = ['winter', 'Summer', 'Fall', 'Spring']
weather = ['few clouds', 'mist', 'light rain', '4']

# Create the plot
plt.figure(figsize=(10, 6))
bars = plt.bar(season, weather, color=sns.color_palette("viridis", 5))

# Customize the plot
plt.title('Bar Graph', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Weather', fontsize=12)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height}',
             ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Dataset 2

# %%
import numpy as np
import pandas as pd

# %%
dataset_2= r"C:\Users\DELL\Documents\dataset_2.csv"
df2 = pd.read_csv(dataset_2)
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
# Drop column 'Unnamed'
df2 = df2.loc[:, ~df2.columns.str.contains('^Unnamed')]
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
df2 = pd.DataFrame(df2)
df2.head()
column_list = list(df2.columns)
column_list
# Out:
# ['instant', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %%
# checking the description
df2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
# Checking for any N/A values
df2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Checking for any duplicates values
df2.duplicated().sum()
# Out:
# 0

# %%
missing_value_df2 = df2.isnull().sum()
print("\n missing value in dataset 2: \n" , missing_value_df2)
# Out:
#  missing value in dataset 2:
#  instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Check data types in datasets
dtype_info_df2 = df2.dtypes
print("\n Data Types in Dataset 2:\n", dtype_info_df2)
# Out:
#  Data Types in Dataset 2:
#  instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Importing Liraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Temperature percentage
colors=['grey', 'blue', 'red', 'yellow', 'lightcoral', 'lightskyblue', 'gold']
counts = df2["atemp"].value_counts()
counts.plot (kind='pie',fontsize=6, autopct= '%1.1f%%', colors=colors)
plt.xlabel('atemp', weight="bold", fontsize=8, labelpad=20)
plt.axis('equal')
plt.legend(labels=counts.index, loc="best")
plt.show()

# %%
# Generate some sample data
x = np.linspace(0, 10)
y = np.sin(x)

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot the data
plt.plot(x, y)

# Add labels and title
plt.xlabel('Weather')
plt.ylabel('Season')
plt.title('Line plot')

# Show the plot
plt.show()

# %%
# Generate Bar Graph
season = ['winter', 'Summer', 'Fall', 'Spring']
weather = ['few clouds', 'mist', 'light rain', '4']

# Create the plot
plt.figure(figsize=(10, 6))
bars = plt.bar(season, weather, color=sns.color_palette("viridis", 5))

# Customize the plot
plt.title('Bar Graph', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Weather', fontsize=12)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height}',
             ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Here, Merging the dataset 1 & 2 , and Concatination

# %%
# Using  a concat() method
df9 = pd.concat([df1, df2], axis=1, join='inner')
df9
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
# Display the both dataset
instant = list(set(df1.columns) & set(df2.columns))
merged_df = pd.merge(df1, df2, on=instant, how='outer')
# Display the merged dataset
display(merged_df)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  instant     610 non-null    int64
#  11  atemp       599 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(11), object(1)
# memory usage: 77.0+ KB

# %%
df9 = pd.DataFrame(df9)
df9.head()
column_list = list(df9.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'instant',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
# CHecking the description
df9.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean     0.196885  305.500000    0.199935    0.562475    0.204851    4.501639
# ...

# %%
# Checking for any duplicates values
df9.duplicated().sum()
# Out:
# 0

# %%
# Checking for any N/A values
df9.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
missing_value_df9 = df9.isnull().sum()
print("\n missing value in dataset 9: \n" , missing_value_df9)
# Out:
#  missing value in dataset 9:
#  instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Importing Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# pie chart shows the Temperature Percentage
sns.set_style('darkgrid')
plt.figure(figsize=(14,6))
plt.pie(df9['atemp'].value_counts(),labels = df9['atemp'].value_counts().index, autopct='%1.1f%%')
plt.title("Temperature")
# Out:
# Text(0.5, 1.0, 'Temperature')

# %%
# pie chart shows the Hourse Percentage
sns.set_style('darkgrid')
plt.figure(figsize=(24,6))
plt.pie(df9['hr'].value_counts(),labels = df9['hr'].value_counts().index, autopct='%1.1f%%')
plt.title("Hours")
# Out:
# Text(0.5, 1.0, 'Hours')

# %% [markdown]
# # Load Dataset-3

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

# %%
dataset_3= r"C:\Users\DELL\Downloads\dataset_3.csv"
df3 = pd.read_csv(dataset_3)
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
df3 =pd.DataFrame(df3)
column_list = list(df3.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
df3.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
df3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
missing_value_df2 = df2.isnull().sum()
print("\n missing value in dataset 2: \n" , missing_value_df2)
# Out:
#  missing value in dataset 2:
#  instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Check data types in datasets
dtype_info_df3 = df3.dtypes
print("\n Data Types in Dataset 3:\n", dtype_info_df3)
# Out:
#  Data Types in Dataset 3:
#  instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df3.shape
# Out:
# (390, 16)

# %%
df3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
df3.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %% [markdown]
# # Data Visualization

# %%
# Humidity in all seasons
Humidity_counts = df9['hum'].value_counts()
plt.figure(figsize=(16, 6))
Humidity_counts.plot(kind='bar', color= 'skyblue')
plt.title('Humidity in all seasons')
plt.xlabel('humidity')
plt.ylabel('season')
plt.xticks(rotation=90, ha='right') # Adjust rotation for better readability 
plt.show()

# %%
# Weathersit in all seasons
weathersit_counts = df9['weathersit'].value_counts()
plt.figure(figsize=(10, 6))
bars = weathersit_counts.plot(kind='bar', color=colors)

for bar, count in zip(bars.patches, weathersit_counts):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.05, str(count), fontsize=10)
plt.title('Weathersit according to seasons')
plt.xlabel('season')
plt.ylabel('weathersit')
plt.xticks(rotation=0, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3'), Text(3, 0, '4')])

# %% [markdown]
# ## Here, Merging the dataset 3 & 9 , and Concatination

# %%
# Using a concat() method
final_df = pd.concat([df3, df9], axis=1, join='inner')
final_df
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
#  16  instant     390 non-null    int64
#  17  dteday      390 non-null    object
#  18  season      390 non-null    int64
# ...

# %%
final_df =pd.DataFrame(final_df)
column_list = list(final_df.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt',
#  'instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'instant',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
# Checking the description
final_df.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum  ...     weekday  \
# count  390.000000  390.000000  390.000000  390.000000  ...  390.000000
# mean     1.484615    0.220000    0.230424    0.613769  ...    2.920513
# std      0.663805    0.073095    0.069455    0.202361  ...    2.160962
# ...

# %%
final_df.isnull().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp          0
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
final_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# Length: 390, dtype: bool

# %%
unique_values={col:final_df[col].nunique() for col in final_df.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': instant    390
# instant    390
# instant    390
# dtype: int64, 'dteday': dteday    18
# dteday    17
# dtype: int64, 'season': season    1
# season    1
# dtype: int64, 'yr': yr    1
# yr    1
# dtype: int64, 'mnth': mnth    2
# mnth    1
# dtype: int64, 'hr': hr    24
# hr    24
# dtype: int64, 'holiday': holiday    1
# holiday    2
# dtype: int64, 'weekday': weekday    7
# weekday    7
# dtype: int64, 'weathersit': weathersit    3
# weathersit    3
# dtype: int64, 'temp': temp    19
# temp    20
# dtype: int64, 'atemp': atemp    22
# atemp    25
# dtype: int64, 'hum': hum    58
# hum    50
# dtype: int64, 'windspeed': windspeed    20
# windspeed    20
# dtype: int64, 'casual': casual    36
# casual    31
# dtype: int64, 'registered': registered    146
# registered    124
# dtype: int64, 'cnt': cnt    144
# cnt    139
# dtype: int64}

# %%
missing_value_final_df = final_df.isnull().sum()
print("\n missing value in dataset final_df: \n" , missing_value_final_df)
# Out:
#  missing value in dataset final_df:
#  instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp          0
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# # Outliers

# %% [markdown]
# #### Importing Libraries

# %%
import scipy

# %%
numeric_cols=final_df.select_dtypes(include=['number']).columns
Q1=final_df[numeric_cols].quantile(0.25)
Q3=final_df[numeric_cols].quantile(0.75)
IQR = Q3-Q1

# %%
outliers = ((final_df[numeric_cols] < (Q1 - 1.5 * IQR)) | (final_df[numeric_cols] > (Q3 + 1.5 * IQR))).sum()
print("Outliers  Count Per Column:\n", outliers)
# Out:
# Outliers  Count Per Column:
#  instant        0
# instant        0
# instant        0
# season         0
# season         0
#               ..
# casual        28
# registered     9
# registered    19
# cnt            8
# cnt           13
# Length: 61, dtype: int64

# %% [markdown]
# ## skewness

# %%
# Calculate the skewness 
numeric_cols_excluding_datetime = final_df.select_dtypes(include=['number']).columns
df_skew = final_df[numeric_cols_excluding_datetime].skew()
df_skew.drop(labels=['season','yr'], errors='ignore', inplace=True)
print("Skewness: \n", df_skew)
# Out:
# Skewness:
#  instant       0.000000
# instant       0.000000
# instant       0.000000
# mnth         -1.505798
# mnth          0.000000
# hr           -0.050086
# hr           -0.034800
# weekday       0.014906
# weekday       0.081522
# weathersit    1.037234
# weathersit    1.171832
# temp          0.479548
# temp          1.369801
# atemp         0.440540
# atemp         1.081665
# hum           0.161484
# hum           0.860553
# windspeed     0.620359
# windspeed     0.266860
# casual        3.413724
# casual        2.624594
# registered    1.115912
# registered    1.366312
# cnt           0.987140
# cnt           1.147964
# instant       0.000000
# instant       0.000000
# instant       0.000000
# mnth         -1.505798
# mnth          0.000000
# hr           -0.050086
# hr           -0.034800
# weekday       0.014906
# weekday       0.081522
# weathersit    1.037234
# weathersit    1.171832
# temp          0.479548
# temp          1.369801
# instant       0.000000
# ...

# %%
# Count of total rental according to data
cnt_counts = df3['cnt'].value_counts()
plt.figure(figsize=(10, 6))
bars = weathersit_counts.plot(kind='bar', color=colors)

for bar, count in zip(bars.patches, weathersit_counts):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.05, str(count), fontsize=10)
plt.title('Count of total rental')
plt.xlabel('season')
plt.ylabel('cnt')
plt.xticks(rotation=0, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3'), Text(3, 0, '4')])

# %%
# Correlation matrix (excluding categorical columns)
numeric_features=final_df.select_dtypes(include=['number']).columns
df_corr = final_df[numeric_features].corr()
print("Correlation Matrix:\n", df_corr)
# Out:
# Correlation Matrix:
#               instant   instant   instant  season  season  yr  yr      mnth  \
# instant     1.000000  0.864733  0.864733     NaN     NaN NaN NaN  0.692823
# instant     0.864733  1.000000  1.000000     NaN     NaN NaN NaN  0.532940
# instant     0.864733  1.000000  1.000000     NaN     NaN NaN NaN  0.532940
# season           NaN       NaN       NaN     NaN     NaN NaN NaN       NaN
# season           NaN       NaN       NaN     NaN     NaN NaN NaN       NaN
# ...              ...       ...       ...     ...     ...  ..  ..       ...
# casual     -0.127018 -0.069315 -0.069315     NaN     NaN NaN NaN -0.263268
# registered  0.041795  0.057559  0.057559     NaN     NaN NaN NaN  0.063073
# registered -0.006387  0.021941  0.021941     NaN     NaN NaN NaN  0.097693
# cnt         0.076839  0.086987  0.086987     NaN     NaN NaN NaN  0.071107
# cnt        -0.025133  0.010367  0.010367     NaN     NaN NaN NaN  0.052974
#
# ...

# %%
#Compute correlation matrix
numeric_features = final_df.select_dtypes(include=['number']).columns
df_corr = final_df[numeric_features].corr()

#Drop columns that contain only NaN volues in the correlation matrix
df_corr_cleaned = df_corr.dropna(how='all', axis=1).dropna(how ='all', axis=0)
print("Cleaned Correlation Matrix:\n", df_corr_cleaned)
# Out:
# Cleaned Correlation Matrix:
#               instant   instant   instant      mnth        hr        hr  \
# instant     1.000000  0.864733  0.864733  0.692823 -0.018596 -0.002380
# instant     0.864733  1.000000  1.000000  0.532940  0.046149  0.013838
# instant     0.864733  1.000000  1.000000  0.532940  0.046149  0.013838
# mnth        0.692823  0.532940  0.532940  1.000000 -0.056458 -0.027374
# hr         -0.018596  0.046149  0.046149 -0.056458  1.000000  0.629711
# hr         -0.002380  0.013838  0.013838 -0.027374  0.629711  1.000000
# weekday     0.000053  0.079035  0.079035  0.093148  0.050662  0.002000
# weekday     0.050089 -0.021048 -0.021048  0.156827 -0.002505  0.012510
# weathersit -0.220022 -0.238264 -0.238264  0.027074 -0.054857 -0.069473
# weathersit -0.074003 -0.004558 -0.004558 -0.151725 -0.004770 -0.022939
# temp        0.164053  0.178654  0.178654  0.126446  0.278821  0.292075
# temp       -0.370810 -0.398058 -0.398058 -0.537188  0.135193  0.187890
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(final_df['cnt'], bins=30, kde=True, color='red')
plt.title("Histogram")
plt.xlabel("Total ")
plt.ylabel ("Frequency")
plt.show()

# %% [markdown]
# ## Heatmap

# %%
#Drop non-numeric columns before correlation analysis
numeric_df = final_df.select_dtypes(include=['int64','float64'])

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(numeric_df.corr(),annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation of data")
plt.show()
